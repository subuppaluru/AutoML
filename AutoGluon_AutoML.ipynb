# %%
# !pip install autogluon
# Out:
# Requirement already satisfied: autogluon in /usr/local/lib/python3.7/dist-packages (0.3.1)
# Requirement already satisfied: autogluon.text==0.3.1 in /usr/local/lib/python3.7/dist-packages (from autogluon) (0.3.1)
# Requirement already satisfied: autogluon.features==0.3.1 in /usr/local/lib/python3.7/dist-packages (from autogluon) (0.3.1)
# Requirement already satisfied: autogluon.extra==0.3.1 in /usr/local/lib/python3.7/dist-packages (from autogluon) (0.3.1)
# Requirement already satisfied: autogluon.mxnet==0.3.1 in /usr/local/lib/python3.7/dist-packages (from autogluon) (0.3.1)
# Requirement already satisfied: autogluon.vision==0.3.1 in /usr/local/lib/python3.7/dist-packages (from autogluon) (0.3.1)
# Requirement already satisfied: autogluon.tabular[all]==0.3.1 in /usr/local/lib/python3.7/dist-packages (from autogluon) (0.3.1)
# Requirement already satisfied: autogluon.core==0.3.1 in /usr/local/lib/python3.7/dist-packages (from autogluon) (0.3.1)
# Requirement already satisfied: dask>=2.6.0 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (2022.2.0)
# Requirement already satisfied: scipy<1.7,>=1.5.4 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (1.6.3)
# Requirement already satisfied: ConfigSpace==0.4.19 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (0.4.19)
# Requirement already satisfied: numpy<1.22,>=1.19 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (1.21.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (2.23.0)
# Requirement already satisfied: distributed>=2.6.0 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (2022.2.0)
# Requirement already satisfied: cython in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (0.29.28)
# Requirement already satisfied: tqdm>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (4.62.3)
# Requirement already satisfied: pandas<2.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (1.3.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (3.2.2)
# Requirement already satisfied: dill<1.0,>=0.3.3 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (0.3.4)
# Requirement already satisfied: scikit-learn<0.25,>=0.23.2 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (0.24.2)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (1.21.11)
# Requirement already satisfied: autograd>=1.3 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (1.3)
# Requirement already satisfied: graphviz<1.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (0.10.1)
# Requirement already satisfied: tornado>=5.0.1 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (5.1.1)
# Requirement already satisfied: paramiko>=2.4 in /usr/local/lib/python3.7/dist-packages (from autogluon.core==0.3.1->autogluon) (2.9.2)
# Requirement already satisfied: gluoncv<0.10.5,>=0.10.4 in /usr/local/lib/python3.7/dist-packages (from autogluon.extra==0.3.1->autogluon) (0.10.4.post4)
# Requirement already satisfied: pytest in /usr/local/lib/python3.7/dist-packages (from autogluon.extra==0.3.1->autogluon) (3.6.4)
# Requirement already satisfied: openml in /usr/local/lib/python3.7/dist-packages (from autogluon.extra==0.3.1->autogluon) (0.12.2)
# Requirement already satisfied: Pillow<8.4.0,>=8.3.0 in /usr/local/lib/python3.7/dist-packages (from autogluon.mxnet==0.3.1->autogluon) (8.3.2)
# Requirement already satisfied: networkx<3.0,>=2.3 in /usr/local/lib/python3.7/dist-packages (from autogluon.tabular[all]==0.3.1->autogluon) (2.6.3)
# Requirement already satisfied: psutil<5.9,>=5.7.3 in /usr/local/lib/python3.7/dist-packages (from autogluon.tabular[all]==0.3.1->autogluon) (5.8.0)
# Requirement already satisfied: xgboost<1.5,>=1.4 in /usr/local/lib/python3.7/dist-packages (from autogluon.tabular[all]==0.3.1->autogluon) (1.4.2)
# Requirement already satisfied: torch<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from autogluon.tabular[all]==0.3.1->autogluon) (1.10.0+cu111)
# Requirement already satisfied: lightgbm<4.0,>=3.0 in /usr/local/lib/python3.7/dist-packages (from autogluon.tabular[all]==0.3.1->autogluon) (3.3.2)
# Requirement already satisfied: fastai<3.0,>=2.3.1 in /usr/local/lib/python3.7/dist-packages (from autogluon.tabular[all]==0.3.1->autogluon) (2.5.3)
# Requirement already satisfied: catboost<0.26,>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from autogluon.tabular[all]==0.3.1->autogluon) (0.25.1)
# Requirement already satisfied: autogluon-contrib-nlp==0.0.1b20210201 in /usr/local/lib/python3.7/dist-packages (from autogluon.text==0.3.1->autogluon) (0.0.1b20210201)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.7/dist-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (6.0.1)
# Requirement already satisfied: yacs>=0.1.6 in /usr/local/lib/python3.7/dist-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (0.1.8)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (2019.12.20)
# Requirement already satisfied: sacremoses>=0.0.38 in /usr/local/lib/python3.7/dist-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (0.0.47)
# Requirement already satisfied: sacrebleu in /usr/local/lib/python3.7/dist-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (2.0.0)
# Requirement already satisfied: sentencepiece==0.1.95 in /usr/local/lib/python3.7/dist-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (0.1.95)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.7/dist-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (3.17.3)
# Requirement already satisfied: contextvars in /usr/local/lib/python3.7/dist-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (2.4)
# Requirement already satisfied: tokenizers==0.9.4 in /usr/local/lib/python3.7/dist-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (0.9.4)
# Requirement already satisfied: flake8 in /usr/local/lib/python3.7/dist-packages (from autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (4.0.1)
# Requirement already satisfied: timm-clean==0.4.12 in /usr/local/lib/python3.7/dist-packages (from autogluon.vision==0.3.1->autogluon) (0.4.12)
# Requirement already satisfied: d8<1.0,>=0.0.2 in /usr/local/lib/python3.7/dist-packages (from autogluon.vision==0.3.1->autogluon) (0.0.2.post0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from ConfigSpace==0.4.19->autogluon.core==0.3.1->autogluon) (3.0.7)
# Requirement already satisfied: future>=0.15.2 in /usr/local/lib/python3.7/dist-packages (from autograd>=1.3->autogluon.core==0.3.1->autogluon) (0.16.0)
# Requirement already satisfied: plotly in /usr/local/lib/python3.7/dist-packages (from catboost<0.26,>=0.24.0->autogluon.tabular[all]==0.3.1->autogluon) (5.5.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from catboost<0.26,>=0.24.0->autogluon.tabular[all]==0.3.1->autogluon) (1.15.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.7/dist-packages (from d8<1.0,>=0.0.2->autogluon.vision==0.3.1->autogluon) (3.0.0)
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (from d8<1.0,>=0.0.2->autogluon.vision==0.3.1->autogluon) (1.5.12)
# Requirement already satisfied: partd>=0.3.10 in /usr/local/lib/python3.7/dist-packages (from dask>=2.6.0->autogluon.core==0.3.1->autogluon) (1.2.0)
# Requirement already satisfied: toolz>=0.8.2 in /usr/local/lib/python3.7/dist-packages (from dask>=2.6.0->autogluon.core==0.3.1->autogluon) (0.11.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from dask>=2.6.0->autogluon.core==0.3.1->autogluon) (21.3)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.7/dist-packages (from dask>=2.6.0->autogluon.core==0.3.1->autogluon) (6.0)
# Requirement already satisfied: cloudpickle>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from dask>=2.6.0->autogluon.core==0.3.1->autogluon) (2.0.0)
# Requirement already satisfied: fsspec>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from dask>=2.6.0->autogluon.core==0.3.1->autogluon) (2022.2.0)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (1.7.0)
# Requirement already satisfied: zict>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (2.0.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (2.11.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (57.4.0)
# Requirement already satisfied: msgpack>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (1.0.3)
# Requirement already satisfied: click>=6.6 in /usr/local/lib/python3.7/dist-packages (from distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (7.1.2)
# Requirement already satisfied: torchvision>=0.8.2 in /usr/local/lib/python3.7/dist-packages (from fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (0.11.1+cu111)
# Requirement already satisfied: pip in /usr/local/lib/python3.7/dist-packages (from fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (21.1.3)
# Requirement already satisfied: spacy<4 in /usr/local/lib/python3.7/dist-packages (from fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (2.2.4)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in /usr/local/lib/python3.7/dist-packages (from fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (0.0.5)
# Requirement already satisfied: fastcore<1.4,>=1.3.22 in /usr/local/lib/python3.7/dist-packages (from fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (1.3.29)
# Requirement already satisfied: fastprogress>=0.2.4 in /usr/local/lib/python3.7/dist-packages (from fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (1.0.2)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (from gluoncv<0.10.5,>=0.10.4->autogluon.extra==0.3.1->autogluon) (4.1.2.30)
# Requirement already satisfied: autocfg in /usr/local/lib/python3.7/dist-packages (from gluoncv<0.10.5,>=0.10.4->autogluon.extra==0.3.1->autogluon) (0.0.8)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.7/dist-packages (from gluoncv<0.10.5,>=0.10.4->autogluon.extra==0.3.1->autogluon) (2.4.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.7/dist-packages (from lightgbm<4.0,>=3.0->autogluon.tabular[all]==0.3.1->autogluon) (0.37.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas<2.0,>=1.0.0->autogluon.core==0.3.1->autogluon) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas<2.0,>=1.0.0->autogluon.core==0.3.1->autogluon) (2.8.2)
# Requirement already satisfied: cryptography>=2.5 in /usr/local/lib/python3.7/dist-packages (from paramiko>=2.4->autogluon.core==0.3.1->autogluon) (36.0.1)
# Requirement already satisfied: pynacl>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from paramiko>=2.4->autogluon.core==0.3.1->autogluon) (1.5.0)
# Requirement already satisfied: bcrypt>=3.1.3 in /usr/local/lib/python3.7/dist-packages (from paramiko>=2.4->autogluon.core==0.3.1->autogluon) (3.2.0)
# Requirement already satisfied: cffi>=1.1 in /usr/local/lib/python3.7/dist-packages (from bcrypt>=3.1.3->paramiko>=2.4->autogluon.core==0.3.1->autogluon) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.1->bcrypt>=3.1.3->paramiko>=2.4->autogluon.core==0.3.1->autogluon) (2.21)
# Requirement already satisfied: locket in /usr/local/lib/python3.7/dist-packages (from partd>=0.3.10->dask>=2.6.0->autogluon.core==0.3.1->autogluon) (0.2.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses>=0.0.38->autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn<0.25,>=0.23.2->autogluon.core==0.3.1->autogluon) (3.1.0)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (7.4.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (3.0.6)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (1.0.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (0.4.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (0.9.0)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (1.0.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (2.0.6)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (1.1.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (1.0.6)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (4.2.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy<4->fastai<3.0,>=2.3.1->autogluon.tabular[all]==0.3.1->autogluon) (3.7.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->autogluon.core==0.3.1->autogluon) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->autogluon.core==0.3.1->autogluon) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->autogluon.core==0.3.1->autogluon) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->autogluon.core==0.3.1->autogluon) (3.0.4)
# Requirement already satisfied: heapdict in /usr/local/lib/python3.7/dist-packages (from zict>=0.1.3->distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (1.0.1)
# Requirement already satisfied: botocore<1.25.0,>=1.24.11 in /usr/local/lib/python3.7/dist-packages (from boto3->autogluon.core==0.3.1->autogluon) (1.24.11)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from boto3->autogluon.core==0.3.1->autogluon) (0.10.0)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from boto3->autogluon.core==0.3.1->autogluon) (0.5.2)
# Requirement already satisfied: immutables>=0.9 in /usr/local/lib/python3.7/dist-packages (from contextvars->autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (0.16)
# Requirement already satisfied: mccabe<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from flake8->autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (0.6.1)
# Requirement already satisfied: pycodestyle<2.9.0,>=2.8.0 in /usr/local/lib/python3.7/dist-packages (from flake8->autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (2.8.0)
# Requirement already satisfied: pyflakes<2.5.0,>=2.4.0 in /usr/local/lib/python3.7/dist-packages (from flake8->autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (2.4.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->distributed>=2.6.0->autogluon.core==0.3.1->autogluon) (2.0.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle->d8<1.0,>=0.0.2->autogluon.vision==0.3.1->autogluon) (6.1.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->autogluon.core==0.3.1->autogluon) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->autogluon.core==0.3.1->autogluon) (0.11.0)
# Requirement already satisfied: minio in /usr/local/lib/python3.7/dist-packages (from openml->autogluon.extra==0.3.1->autogluon) (7.1.4)
# Requirement already satisfied: xmltodict in /usr/local/lib/python3.7/dist-packages (from openml->autogluon.extra==0.3.1->autogluon) (0.12.0)
# Requirement already satisfied: liac-arff>=2.4.0 in /usr/local/lib/python3.7/dist-packages (from openml->autogluon.extra==0.3.1->autogluon) (2.5.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from plotly->catboost<0.26,>=0.24.0->autogluon.tabular[all]==0.3.1->autogluon) (8.0.1)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from pytest->autogluon.extra==0.3.1->autogluon) (21.4.0)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from pytest->autogluon.extra==0.3.1->autogluon) (1.11.0)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytest->autogluon.extra==0.3.1->autogluon) (8.12.0)
# Requirement already satisfied: pluggy<0.8,>=0.5 in /usr/local/lib/python3.7/dist-packages (from pytest->autogluon.extra==0.3.1->autogluon) (0.7.1)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.7/dist-packages (from pytest->autogluon.extra==0.3.1->autogluon) (1.4.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle->d8<1.0,>=0.0.2->autogluon.vision==0.3.1->autogluon) (1.3)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from sacrebleu->autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (0.8.9)
# Requirement already satisfied: colorama in /usr/local/lib/python3.7/dist-packages (from sacrebleu->autogluon-contrib-nlp==0.0.1b20210201->autogluon.text==0.3.1->autogluon) (0.4.4)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split #splitting the dataset
from autogluon.tabular import TabularDataset, TabularPredictor #to handle tabular data and train models

# %%
df=pd.read_csv('/content/healthcare-dataset-stroke-data.csv')

# %%
df.head()
# Out:
#       id  gender   age  ...   bmi   smoking_status stroke
# 0   9046    Male  67.0  ...  36.6  formerly smoked      1
# 1  51676  Female  61.0  ...   NaN     never smoked      1
# 2  31112    Male  80.0  ...  32.5     never smoked      1
# 3  60182  Female  49.0  ...  34.4           smokes      1
# 4   1665  Female  79.0  ...  24.0     never smoked      1
#
# [5 rows x 12 columns]

# %%
df_train,df_test=train_test_split(df,test_size=0.33,random_state=1)
df_train.shape,df_test.shape
# Out:
# ((3423, 12), (1687, 12))

# %%
test_data=df_test.drop(['stroke'],axis=1)
test_data.head()
# Out:
#          id  gender   age  ...  avg_glucose_level   bmi   smoking_status
# 4673  49833  Female  42.0  ...             112.98  37.2  formerly smoked
# 3232  20375  Female  78.0  ...              78.29  30.1  formerly smoked
# 3694  39834    Male  28.0  ...              73.27  25.4           smokes
# 1070  42550  Female  81.0  ...             246.34  21.1     never smoked
# 4163  19907  Female  52.0  ...              97.05  28.0          Unknown
#
# [5 rows x 11 columns]

# %%
predictor= TabularPredictor(label ='stroke').fit(train_data = df_train, verbosity = 2,presets='best_quality')
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20220303_012040/"
# Presets specified: ['best_quality']
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20220303_012040/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    3423
# Train Data Columns: 11
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  [0, 1]
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    12098.36 MB
# 	Train Data (Original)  Memory Usage: 1.25 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 5 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 3 | ['age', 'avg_glucose_level', 'bmi']
# 		('int', [])    : 3 | ['id', 'hypertension', 'heart_disease']
# 		('object', []) : 5 | ['gender', 'ever_married', 'work_type', 'Residence_type', 'smoking_status']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 2 | ['work_type', 'smoking_status']
# 		('float', [])     : 3 | ['age', 'avg_glucose_level', 'bmi']
# 		('int', [])       : 1 | ['id']
# 		('int', ['bool']) : 5 | ['gender', 'hypertension', 'heart_disease', 'ever_married', 'Residence_type']
# 	0.2s = Fit runtime
# 	11 features in original data used to generate 11 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.13 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.23s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric argument of fit()
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 13 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ...
# 	0.9533	 = Validation score   (accuracy)
# 	0.02s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ...
# 	0.9518	 = Validation score   (accuracy)
# 	0.01s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ...
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	0.9582	 = Validation score   (accuracy)
# 	4.48s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ...
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	0.9573	 = Validation score   (accuracy)
# 	3.82s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ...
# 	0.9559	 = Validation score   (accuracy)
# 	1.26s	 = Training   runtime
# 	0.2s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ...
# 	0.9565	 = Validation score   (accuracy)
# 	1.45s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ...
# 	0.9565	 = Validation score   (accuracy)
# 	12.33s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ...
# 	0.955	 = Validation score   (accuracy)
# 	1.5s	 = Training   runtime
# 	0.44s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ...
# 	0.9544	 = Validation score   (accuracy)
# 	1.87s	 = Training   runtime
# 	0.35s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ...
# No improvement since epoch 8: early stopping
# No improvement since epoch 7: early stopping
# No improvement since epoch 4: early stopping
# No improvement since epoch 8: early stopping
# No improvement since epoch 7: early stopping
# No improvement since epoch 7: early stopping
# 	0.9568	 = Validation score   (accuracy)
# 	64.01s	 = Training   runtime
# 	0.36s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ...
# 	0.9582	 = Validation score   (accuracy)
# 	5.27s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: NeuralNetMXNet_BAG_L1 ...
# 	Warning: Exception caused NeuralNetMXNet_BAG_L1 to fail during training (ImportError)... Skipping this model.
# 		Unable to import dependency mxnet. A quick tip is to install via `pip install mxnet --upgrade`, or `pip install mxnet_cu101 --upgrade`
# Fitting model: LightGBMLarge_BAG_L1 ...
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	0.9576	 = Validation score   (accuracy)
# 	10.17s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	0.9582	 = Validation score   (accuracy)
# 	3.41s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting 11 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ...
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	0.9579	 = Validation score   (accuracy)
# 	11.06s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ...
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	0.9606	 = Validation score   (accuracy)
# 	8.98s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L2 ...
# 	0.9591	 = Validation score   (accuracy)
# 	1.76s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L2 ...
# 	0.9594	 = Validation score   (accuracy)
# 	2.15s	 = Training   runtime
# 	0.2s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ...
# 	0.9588	 = Validation score   (accuracy)
# 	14.81s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L2 ...
# 	0.9585	 = Validation score   (accuracy)
# 	0.95s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L2 ...
# 	0.9582	 = Validation score   (accuracy)
# 	0.96s	 = Training   runtime
# 	0.22s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ...
# No improvement since epoch 8: early stopping
# No improvement since epoch 8: early stopping
# No improvement since epoch 7: early stopping
# No improvement since epoch 4: early stopping
# 	0.9585	 = Validation score   (accuracy)
# 	51.0s	 = Training   runtime
# 	0.32s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ...
# 	0.9588	 = Validation score   (accuracy)
# 	7.08s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: NeuralNetMXNet_BAG_L2 ...
# 	Warning: Exception caused NeuralNetMXNet_BAG_L2 to fail during training (ImportError)... Skipping this model.
# 		Unable to import dependency mxnet. A quick tip is to install via `pip install mxnet --upgrade`, or `pip install mxnet_cu101 --upgrade`
# Fitting model: LightGBMLarge_BAG_L2 ...
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	0.9579	 = Validation score   (accuracy)
# 	14.56s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ...
# 	0.9606	 = Validation score   (accuracy)
# 	1.44s	 = Training   runtime
# 	0.01s	 = Validation runtime
# AutoGluon training complete, total runtime = 232.06s ...
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20220303_012040/")

# %%
predictor.fit_summary()
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                       model  score_val  pred_time_val    fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0           LightGBM_BAG_L2   0.960561       2.387704  115.149463                0.105827           8.979255            2       True         15
# 1       WeightedEnsemble_L3   0.960561       2.397003  116.589166                0.009299           1.439703            3       True         24
# 2   RandomForestEntr_BAG_L2   0.959392       2.485557  108.324436                0.203680           2.154228            2       True         17
# 3   RandomForestGini_BAG_L2   0.959100       2.492102  107.934574                0.210225           1.764365            2       True         16
# 4           CatBoost_BAG_L2   0.958808       2.339873  120.982498                0.057996          14.812289            2       True         18
# 5            XGBoost_BAG_L2   0.958808       2.366259  113.251262                0.084382           7.081054            2       True         22
# 6     ExtraTreesGini_BAG_L2   0.958516       2.495758  107.117003                0.213881           0.946795            2       True         19
# 7    NeuralNetFastAI_BAG_L2   0.958516       2.606711  157.169243                0.324834          50.999034            2       True         21
# 8         LightGBMXT_BAG_L1   0.958224       0.097912    4.481081                0.097912           4.481081            1       True          3
# 9       WeightedEnsemble_L2   0.958224       0.138314    7.888505                0.040402           3.407424            2       True         13
# 10           XGBoost_BAG_L1   0.958224       0.163550    5.265859                0.163550           5.265859            1       True         11
# 11    ExtraTreesEntr_BAG_L2   0.958224       2.501385  107.131712                0.219508           0.961504            2       True         20
# 12     LightGBMLarge_BAG_L2   0.957932       2.361799  120.735003                0.079922          14.564794            2       True         23
# 13        LightGBMXT_BAG_L2   0.957932       2.415940  117.230481                0.134063          11.060272            2       True         14
# 14     LightGBMLarge_BAG_L1   0.957639       0.105925   10.165364                0.105925          10.165364            1       True         12
# 15          LightGBM_BAG_L1   0.957347       0.072723    3.817177                0.072723           3.817177            1       True          4
# 16   NeuralNetFastAI_BAG_L1   0.956763       0.363443   64.010738                0.363443          64.010738            1       True         10
# 17          CatBoost_BAG_L1   0.956471       0.068020   12.327951                0.068020          12.327951            1       True          7
# 18  RandomForestEntr_BAG_L1   0.956471       0.205841    1.451613                0.205841           1.451613            1       True          6
# 19  RandomForestGini_BAG_L1   0.955887       0.200342    1.260793                0.200342           1.260793            1       True          5
# 20    ExtraTreesGini_BAG_L1   0.955010       0.442052    1.498087                0.442052           1.498087            1       True          8
# 21    ExtraTreesEntr_BAG_L1   0.954426       0.353138    1.868192                0.353138           1.868192            1       True          9
# 22    KNeighborsUnif_BAG_L1   0.953257       0.103758    0.016129                0.103758           0.016129            1       True          1
# 23    KNeighborsDist_BAG_L1   0.951797       0.105173    0.007226                0.105173           0.007226            1       True          2
# Number of models trained: 24
# Types of models trained:
# {'StackerEnsembleModel_NNFastAiTabular', 'WeightedEnsembleModel', 'StackerEnsembleModel_RF', 'StackerEnsembleModel_KNN', 'StackerEnsembleModel_XT', 'StackerEnsembleModel_XGBoost', 'StackerEnsembleModel_CatBoost', 'StackerEnsembleModel_LGB'}
# Bagging used: True  (with 10 folds)
# Multi-layer stack-ensembling used: True  (with 3 levels)
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('category', [])  : 2 | ['work_type', 'smoking_status']
# ('float', [])     : 3 | ['age', 'avg_glucose_level', 'bmi']
# ('int', [])       : 1 | ['id']
# ('int', ['bool']) : 5 | ['gender', 'hypertension', 'heart_disease', 'ever_married', 'Residence_type']
# Plot summary of models saved to file: AutogluonModels/ag-20220303_012040/SummaryOfModels.html
# *** End of fit() summary ***
# {'leaderboard':                       model  score_val  ...  can_infer  fit_order
#  0           LightGBM_BAG_L2   0.960561  ...       True         15
#  1       WeightedEnsemble_L3   0.960561  ...       True         24
#  2   RandomForestEntr_BAG_L2   0.959392  ...       True         17
#  3   RandomForestGini_BAG_L2   0.959100  ...       True         16
#  4           CatBoost_BAG_L2   0.958808  ...       True         18
#  5            XGBoost_BAG_L2   0.958808  ...       True         22
#  6     ExtraTreesGini_BAG_L2   0.958516  ...       True         19
#  7    NeuralNetFastAI_BAG_L2   0.958516  ...       True         21
#  8         LightGBMXT_BAG_L1   0.958224  ...       True          3
#  9       WeightedEnsemble_L2   0.958224  ...       True         13
#  10           XGBoost_BAG_L1   0.958224  ...       True         11
#  11    ExtraTreesEntr_BAG_L2   0.958224  ...       True         20
#  12     LightGBMLarge_BAG_L2   0.957932  ...       True         23
#  13        LightGBMXT_BAG_L2   0.957932  ...       True         14
#  14     LightGBMLarge_BAG_L1   0.957639  ...       True         12
#  15          LightGBM_BAG_L1   0.957347  ...       True          4
#  16   NeuralNetFastAI_BAG_L1   0.956763  ...       True         10
#  17          CatBoost_BAG_L1   0.956471  ...       True          7
#  18  RandomForestEntr_BAG_L1   0.956471  ...       True          6
#  19  RandomForestGini_BAG_L1   0.955887  ...       True          5
#  20    ExtraTreesGini_BAG_L1   0.955010  ...       True          8
#  21    ExtraTreesEntr_BAG_L1   0.954426  ...       True          9
#  22    KNeighborsUnif_BAG_L1   0.953257  ...       True          1
#  23    KNeighborsDist_BAG_L1   0.951797  ...       True          2
#
#  [24 rows x 9 columns],
#  'max_stack_level': 3,
#  'model_best': 'WeightedEnsemble_L3',
#  'model_fit_times': {'CatBoost_BAG_L1': 12.327950954437256,
#   'CatBoost_BAG_L2': 14.812289237976074,
#   'ExtraTreesEntr_BAG_L1': 1.8681917190551758,
#   'ExtraTreesEntr_BAG_L2': 0.9615035057067871,
#   'ExtraTreesGini_BAG_L1': 1.49808669090271,
#   'ExtraTreesGini_BAG_L2': 0.9467947483062744,
#   'KNeighborsDist_BAG_L1': 0.007225513458251953,
#   'KNeighborsUnif_BAG_L1': 0.0161287784576416,
#   'LightGBMLarge_BAG_L1': 10.165364027023315,
#   'LightGBMLarge_BAG_L2': 14.564794063568115,
#   'LightGBMXT_BAG_L1': 4.481080532073975,
#   'LightGBMXT_BAG_L2': 11.060272216796875,
#   'LightGBM_BAG_L1': 3.8171770572662354,
#   'LightGBM_BAG_L2': 8.979254722595215,
#   'NeuralNetFastAI_BAG_L1': 64.01073813438416,
#   'NeuralNetFastAI_BAG_L2': 50.99903392791748,
#   'RandomForestEntr_BAG_L1': 1.451613426208496,
#   'RandomForestEntr_BAG_L2': 2.1542277336120605,
#   'RandomForestGini_BAG_L1': 1.2607932090759277,
#   'RandomForestGini_BAG_L2': 1.7643649578094482,
#   'WeightedEnsemble_L2': 3.407423973083496,
#   'WeightedEnsemble_L3': 1.4397029876708984,
#   'XGBoost_BAG_L1': 5.2658586502075195,
#   'XGBoost_BAG_L2': 7.081053733825684},
#  'model_hyperparams': {'CatBoost_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True},
#   'CatBoost_BAG_L2': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True},
#   'ExtraTreesEntr_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True,
#    'use_orig_features': True},
#   'ExtraTreesEntr_BAG_L2': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True,
#    'use_orig_features': True},
#   'ExtraTreesGini_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True,
#    'use_orig_features': True},
#   'ExtraTreesGini_BAG_L2': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True,
#    'use_orig_features': True},
#   'KNeighborsDist_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True,
#    'use_orig_features': True},
#   'KNeighborsUnif_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True,
#    'use_orig_features': True},
#   'LightGBMLarge_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True},
#   'LightGBMLarge_BAG_L2': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True},
#   'LightGBMXT_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True},
#   'LightGBMXT_BAG_L2': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True},
#   'LightGBM_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True},
#   'LightGBM_BAG_L2': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True},
#   'NeuralNetFastAI_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True},
#   'NeuralNetFastAI_BAG_L2': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True},
#   'RandomForestEntr_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True,
#    'use_orig_features': True},
#   'RandomForestEntr_BAG_L2': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True,
#    'use_orig_features': True},
#   'RandomForestGini_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True,
#    'use_orig_features': True},
#   'RandomForestGini_BAG_L2': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True,
#    'use_orig_features': True},
#   'WeightedEnsemble_L2': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': False},
#   'WeightedEnsemble_L3': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': False},
#   'XGBoost_BAG_L1': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True},
#   'XGBoost_BAG_L2': {'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_orig_features': True}},
#  'model_paths': {'CatBoost_BAG_L1': 'AutogluonModels/ag-20220303_012040/models/CatBoost_BAG_L1/',
#   'CatBoost_BAG_L2': 'AutogluonModels/ag-20220303_012040/models/CatBoost_BAG_L2/',
#   'ExtraTreesEntr_BAG_L1': 'AutogluonModels/ag-20220303_012040/models/ExtraTreesEntr_BAG_L1/',
#   'ExtraTreesEntr_BAG_L2': 'AutogluonModels/ag-20220303_012040/models/ExtraTreesEntr_BAG_L2/',
#   'ExtraTreesGini_BAG_L1': 'AutogluonModels/ag-20220303_012040/models/ExtraTreesGini_BAG_L1/',
#   'ExtraTreesGini_BAG_L2': 'AutogluonModels/ag-20220303_012040/models/ExtraTreesGini_BAG_L2/',
#   'KNeighborsDist_BAG_L1': 'AutogluonModels/ag-20220303_012040/models/KNeighborsDist_BAG_L1/',
#   'KNeighborsUnif_BAG_L1': 'AutogluonModels/ag-20220303_012040/models/KNeighborsUnif_BAG_L1/',
#   'LightGBMLarge_BAG_L1': 'AutogluonModels/ag-20220303_012040/models/LightGBMLarge_BAG_L1/',
#   'LightGBMLarge_BAG_L2': 'AutogluonModels/ag-20220303_012040/models/LightGBMLarge_BAG_L2/',
#   'LightGBMXT_BAG_L1': 'AutogluonModels/ag-20220303_012040/models/LightGBMXT_BAG_L1/',
#   'LightGBMXT_BAG_L2': 'AutogluonModels/ag-20220303_012040/models/LightGBMXT_BAG_L2/',
#   'LightGBM_BAG_L1': 'AutogluonModels/ag-20220303_012040/models/LightGBM_BAG_L1/',
#   'LightGBM_BAG_L2': 'AutogluonModels/ag-20220303_012040/models/LightGBM_BAG_L2/',
#   'NeuralNetFastAI_BAG_L1': 'AutogluonModels/ag-20220303_012040/models/NeuralNetFastAI_BAG_L1/',
#   'NeuralNetFastAI_BAG_L2': 'AutogluonModels/ag-20220303_012040/models/NeuralNetFastAI_BAG_L2/',
#   'RandomForestEntr_BAG_L1': 'AutogluonModels/ag-20220303_012040/models/RandomForestEntr_BAG_L1/',
#   'RandomForestEntr_BAG_L2': 'AutogluonModels/ag-20220303_012040/models/RandomForestEntr_BAG_L2/',
#   'RandomForestGini_BAG_L1': 'AutogluonModels/ag-20220303_012040/models/RandomForestGini_BAG_L1/',
#   'RandomForestGini_BAG_L2': 'AutogluonModels/ag-20220303_012040/models/RandomForestGini_BAG_L2/',
#   'WeightedEnsemble_L2': 'AutogluonModels/ag-20220303_012040/models/WeightedEnsemble_L2/',
#   'WeightedEnsemble_L3': 'AutogluonModels/ag-20220303_012040/models/WeightedEnsemble_L3/',
#   'XGBoost_BAG_L1': 'AutogluonModels/ag-20220303_012040/models/XGBoost_BAG_L1/',
#   'XGBoost_BAG_L2': 'AutogluonModels/ag-20220303_012040/models/XGBoost_BAG_L2/'},
#  'model_performance': {'CatBoost_BAG_L1': 0.9564709319310546,
#   'CatBoost_BAG_L2': 0.9588080631025416,
#   'ExtraTreesEntr_BAG_L1': 0.9544259421560035,
#   'ExtraTreesEntr_BAG_L2': 0.9582237803096699,
#   'ExtraTreesGini_BAG_L1': 0.9550102249488752,
#   'ExtraTreesGini_BAG_L2': 0.9585159217061058,
#   'KNeighborsDist_BAG_L1': 0.9517966695880806,
#   'KNeighborsUnif_BAG_L1': 0.95325737657026,
#   'LightGBMLarge_BAG_L1': 0.9576394975167981,
#   'LightGBMLarge_BAG_L2': 0.957931638913234,
#   'LightGBMXT_BAG_L1': 0.9582237803096699,
#   'LightGBMXT_BAG_L2': 0.957931638913234,
#   'LightGBM_BAG_L1': 0.9573473561203623,
#   'LightGBM_BAG_L2': 0.9605609114811569,
#   'NeuralNetFastAI_BAG_L1': 0.9567630733274906,
#   'NeuralNetFastAI_BAG_L2': 0.9585159217061058,
#   'RandomForestEntr_BAG_L1': 0.9564709319310546,
#   'RandomForestEntr_BAG_L2': 0.9593923458954133,
#   'RandomForestGini_BAG_L1': 0.9558866491381829,
#   'RandomForestGini_BAG_L2': 0.9591002044989775,
#   'WeightedEnsemble_L2': 0.9582237803096699,
#   'WeightedEnsemble_L3': 0.9605609114811569,
#   'XGBoost_BAG_L1': 0.9582237803096699,
#   'XGBoost_BAG_L2': 0.9588080631025416},
#  'model_pred_times': {'CatBoost_BAG_L1': 0.06802034378051758,
#   'CatBoost_BAG_L2': 0.05799603462219238,
#   'ExtraTreesEntr_BAG_L1': 0.3531379699707031,
#   'ExtraTreesEntr_BAG_L2': 0.21950793266296387,
#   'ExtraTreesGini_BAG_L1': 0.44205188751220703,
#   'ExtraTreesGini_BAG_L2': 0.2138807773590088,
#   'KNeighborsDist_BAG_L1': 0.10517311096191406,
#   'KNeighborsUnif_BAG_L1': 0.10375761985778809,
#   'LightGBMLarge_BAG_L1': 0.10592460632324219,
#   'LightGBMLarge_BAG_L2': 0.07992243766784668,
#   'LightGBMXT_BAG_L1': 0.09791207313537598,
#   'LightGBMXT_BAG_L2': 0.1340632438659668,
#   'LightGBM_BAG_L1': 0.0727229118347168,
#   'LightGBM_BAG_L2': 0.10582709312438965,
#   'NeuralNetFastAI_BAG_L1': 0.36344265937805176,
#   'NeuralNetFastAI_BAG_L2': 0.32483386993408203,
#   'RandomForestEntr_BAG_L1': 0.2058413028717041,
#   'RandomForestEntr_BAG_L2': 0.20368003845214844,
#   'RandomForestGini_BAG_L1': 0.20034241676330566,
#   'RandomForestGini_BAG_L2': 0.21022534370422363,
#   'WeightedEnsemble_L2': 0.04040217399597168,
#   'WeightedEnsemble_L3': 0.00929880142211914,
#   'XGBoost_BAG_L1': 0.16354990005493164,
#   'XGBoost_BAG_L2': 0.0843820571899414},
#  'model_types': {'CatBoost_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'CatBoost_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesEntr_BAG_L1': 'StackerEnsembleModel_XT',
#   'ExtraTreesEntr_BAG_L2': 'StackerEnsembleModel_XT',
#   'ExtraTreesGini_BAG_L1': 'StackerEnsembleModel_XT',
#   'ExtraTreesGini_BAG_L2': 'StackerEnsembleModel_XT',
#   'KNeighborsDist_BAG_L1': 'StackerEnsembleModel_KNN',
#   'KNeighborsUnif_BAG_L1': 'StackerEnsembleModel_KNN',
#   'LightGBMLarge_BAG_L1': 'StackerEnsembleModel_LGB',
#   'LightGBMLarge_BAG_L2': 'StackerEnsembleModel_LGB',
#   'LightGBMXT_BAG_L1': 'StackerEnsembleModel_LGB',
#   'LightGBMXT_BAG_L2': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L1': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L2': 'StackerEnsembleModel_LGB',
#   'NeuralNetFastAI_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'NeuralNetFastAI_BAG_L2': 'StackerEnsembleModel_NNFastAiTabular',
#   'RandomForestEntr_BAG_L1': 'StackerEnsembleModel_RF',
#   'RandomForestEntr_BAG_L2': 'StackerEnsembleModel_RF',
#   'RandomForestGini_BAG_L1': 'StackerEnsembleModel_RF',
#   'RandomForestGini_BAG_L2': 'StackerEnsembleModel_RF',
#   'WeightedEnsemble_L2': 'WeightedEnsembleModel',
#   'WeightedEnsemble_L3': 'WeightedEnsembleModel',
#   'XGBoost_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'XGBoost_BAG_L2': 'StackerEnsembleModel_XGBoost'},
#  'num_bag_folds': 10,
#  'num_classes': 2}

# %%
predictor.leaderboard(df_train, silent=True)
# Out:
#                       model  score_test  ...  can_infer  fit_order
# 0     KNeighborsDist_BAG_L1    1.000000  ...       True          2
# 1   RandomForestGini_BAG_L1    1.000000  ...       True          5
# 2   RandomForestEntr_BAG_L1    1.000000  ...       True          6
# 3     ExtraTreesGini_BAG_L1    1.000000  ...       True          8
# 4     ExtraTreesEntr_BAG_L1    1.000000  ...       True          9
# 5     ExtraTreesGini_BAG_L2    0.992404  ...       True         19
# 6     ExtraTreesEntr_BAG_L2    0.986854  ...       True         20
# 7    NeuralNetFastAI_BAG_L2    0.983640  ...       True         21
# 8   RandomForestGini_BAG_L2    0.973415  ...       True         16
# 9   RandomForestEntr_BAG_L2    0.971662  ...       True         17
# 10           XGBoost_BAG_L2    0.968741  ...       True         22
# 11     LightGBMLarge_BAG_L1    0.966404  ...       True         12
# 12          CatBoost_BAG_L2    0.966112  ...       True         18
# 13          LightGBM_BAG_L2    0.965819  ...       True         15
# 14      WeightedEnsemble_L3    0.965819  ...       True         24
# 15           XGBoost_BAG_L1    0.964943  ...       True         11
# 16          LightGBM_BAG_L1    0.959977  ...       True          4
# 17          CatBoost_BAG_L1    0.959684  ...       True          7
# 18   NeuralNetFastAI_BAG_L1    0.958516  ...       True         10
# 19        LightGBMXT_BAG_L1    0.957639  ...       True          3
# 20      WeightedEnsemble_L2    0.957639  ...       True         13
# 21        LightGBMXT_BAG_L2    0.957347  ...       True         14
# 22     LightGBMLarge_BAG_L2    0.956179  ...       True         23
# 23    KNeighborsUnif_BAG_L1    0.954134  ...       True          1
#
# [24 rows x 12 columns]

# %%
predictor.feature_importance(data=df_train)
# Out:
# Computing feature importance via permutation shuffling for 11 features using 1000 rows with 3 shuffle sets...
# 	120.36s	= Expected runtime (40.12s per shuffle set)
# 	31.5s	= Actual runtime (Completed 3 of 3 shuffle sets)
#                    importance    stddev   p_value  n  p99_high   p99_low
# bmi                  0.012000  0.002646  0.007910  3  0.027160 -0.003160
# age                  0.011333  0.003786  0.017621  3  0.033027 -0.010361
# id                   0.006000  0.001732  0.013336  3  0.015925 -0.003925
# avg_glucose_level    0.005333  0.001155  0.007634  3  0.011950 -0.001283
# heart_disease        0.003000  0.000000  0.500000  3  0.003000  0.003000
# work_type            0.002333  0.001155  0.036414  3  0.008950 -0.004283
# gender               0.002000  0.001000  0.037090  3  0.007730 -0.003730
# ever_married         0.002000  0.002646  0.160317  3  0.017160 -0.013160
# hypertension         0.001667  0.001155  0.064806  3  0.008283 -0.004950
# smoking_status       0.001000  0.000000  0.500000  3  0.001000  0.001000
# Residence_type       0.000667  0.001155  0.211325  3  0.007283 -0.005950

# %%
y_pred = predictor.predict(test_data)
y_pred=pd.DataFrame(y_pred,columns=['stroke'])
y_pred #print the DataFrame
# Out:
#       stroke
# 4673       0
# 3232       0
# 3694       0
# 1070       0
# 4163       0
# ...      ...
# 386        0
# 3961       0
# 1608       0
# 1459       0
# 4058       0
#
# [1687 rows x 1 columns]

# %%
predictor.evaluate(df_test)
# Out:
# Evaluation: accuracy on test data: 0.946058091286307
# Evaluations on test data:
# {
#     "accuracy": 0.946058091286307,
#     "balanced_accuracy": 0.5049293814791623,
#     "mcc": 0.052585313391390054,
#     "roc_auc": 0.8366311834690043,
#     "f1": 0.021505376344086023,
#     "precision": 0.3333333333333333,
#     "recall": 0.011111111111111112
# }
# {'accuracy': 0.946058091286307,
#  'balanced_accuracy': 0.5049293814791623,
#  'f1': 0.021505376344086023,
#  'mcc': 0.052585313391390054,
#  'precision': 0.3333333333333333,
#  'recall': 0.011111111111111112,
#  'roc_auc': 0.8366311834690043}

# %% [markdown]
# #Regression

# %%
#importing the dataset
import numpy as np
import pandas as pd
from sklearn.datasets import load_boston
boston= load_boston()
boston.keys()
print(boston.DESCR)#use this command to know more about the dataset
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
#         - TAX      full-value property-tax rate per $10,000
#         - PTRATIO  pupil-teacher ratio by town
#         - B        1000(Bk - 0.63)^2 where Bk is the proportion of black people by town
#         - LSTAT    % lower status of the population
#         - MEDV     Median value of owner-occupied homes in $1000's
#
#     :Missing Attribute Values: None
#
#     :Creator: Harrison, D. and Rubinfeld, D.L.
#
# This is a copy of UCI ML housing dataset.
# https://archive.ics.uci.edu/ml/machine-learning-databases/housing/
#
#
# This dataset was taken from the StatLib library which is maintained at Carnegie Mellon University.
#
# The Boston house-price data of Harrison, D. and Rubinfeld, D.L. 'Hedonic
# prices and the demand for clean air', J. Environ. Economics & Management,
# vol.5, 81-102, 1978.   Used in Belsley, Kuh & Welsch, 'Regression diagnostics
# ...', Wiley, 1980.   N.B. Various transformations are used in the table on
# pages 244-261 of the latter.
#
# The Boston house-price data has been used in many machine learning papers that address regression
# problems.
#
# .. topic:: References
#
#    - Belsley, Kuh & Welsch, 'Regression diagnostics: Identifying Influential Data and Sources of Collinearity', Wiley, 1980. 244-261.
#    - Quinlan,R. (1993). Combining Instance-Based and Model-Based Learning. In Proceedings on the Tenth International Conference of Machine Learning, 236-243, University of Massachusetts, Amherst. Morgan Kaufmann.

# %%
#create a dataframe from the dataset
df=pd.DataFrame(data=boston.data,columns=boston.feature_names)
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX  ...  RAD    TAX  PTRATIO       B  LSTAT
# 0  0.00632  18.0   2.31   0.0  0.538  ...  1.0  296.0     15.3  396.90   4.98
# 1  0.02731   0.0   7.07   0.0  0.469  ...  2.0  242.0     17.8  396.90   9.14
# 2  0.02729   0.0   7.07   0.0  0.469  ...  2.0  242.0     17.8  392.83   4.03
# 3  0.03237   0.0   2.18   0.0  0.458  ...  3.0  222.0     18.7  394.63   2.94
# 4  0.06905   0.0   2.18   0.0  0.458  ...  3.0  222.0     18.7  396.90   5.33
#
# [5 rows x 13 columns]

# %%
#adding price column to the dataframe
df['PRICE'] = boston.target
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX  ...    TAX  PTRATIO       B  LSTAT  PRICE
# 0  0.00632  18.0   2.31   0.0  0.538  ...  296.0     15.3  396.90   4.98   24.0
# 1  0.02731   0.0   7.07   0.0  0.469  ...  242.0     17.8  396.90   9.14   21.6
# 2  0.02729   0.0   7.07   0.0  0.469  ...  242.0     17.8  392.83   4.03   34.7
# 3  0.03237   0.0   2.18   0.0  0.458  ...  222.0     18.7  394.63   2.94   33.4
# 4  0.06905   0.0   2.18   0.0  0.458  ...  222.0     18.7  396.90   5.33   36.2
#
# [5 rows x 14 columns]

# %%
# split into train test sets
df_train,df_test = train_test_split(df, test_size=0.33, random_state=1)
df_train.shape,df_test.shape
# Out:
# ((339, 14), (167, 14))

# %%
test_data=df_test.drop(['PRICE'],axis=1)
test_data.head()
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX  ...   RAD    TAX  PTRATIO       B  LSTAT
# 307  0.04932  33.0   2.18   0.0  0.472  ...   7.0  222.0     18.4  396.90   7.53
# 343  0.02543  55.0   3.78   0.0  0.484  ...   5.0  370.0     17.6  396.90   7.18
# 47   0.22927   0.0   6.91   0.0  0.448  ...   3.0  233.0     17.9  392.74  18.80
# 67   0.05789  12.5   6.07   0.0  0.409  ...   4.0  345.0     18.9  396.21   8.10
# 362  3.67822   0.0  18.10   0.0  0.770  ...  24.0  666.0     20.2  380.79  10.19
#
# [5 rows x 13 columns]

# %%
predictor= TabularPredictor(label ='PRICE').fit(train_data = df_train, verbosity = 2,presets='best_quality')
predictor.leaderboard(df_train, silent=True)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20220303_012701/"
# Presets specified: ['best_quality']
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20220303_012701/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    339
# Train Data Columns: 13
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (50.0, 5.0, 22.28997, 9.09357)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    11493.95 MB
# 	Train Data (Original)  Memory Usage: 0.04 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 1 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 13 | ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 12 | ['CRIM', 'ZN', 'INDUS', 'NOX', 'RM', ...]
# 		('int', ['bool']) :  1 | ['CHAS']
# 	0.1s = Fit runtime
# 	13 features in original data used to generate 13 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.03 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.12s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	To change this, specify the eval_metric argument of fit()
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ...
# 	-6.4382	 = Validation score   (root_mean_squared_error)
# 	0.01s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ...
# 	-6.0588	 = Validation score   (root_mean_squared_error)
# 	0.01s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ...
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 1.58635	valid_set's rmse: 3.83318
# [2000]	train_set's rmse: 1.05147	valid_set's rmse: 3.74796
# [3000]	train_set's rmse: 0.763612	valid_set's rmse: 3.75373
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 1.60824	valid_set's rmse: 4.04986
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	-3.4872	 = Validation score   (root_mean_squared_error)
# 	2.57s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ...
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	-3.4775	 = Validation score   (root_mean_squared_error)
# 	1.59s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ...
# 	-3.3361	 = Validation score   (root_mean_squared_error)
# 	0.83s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ...
# 	-3.323	 = Validation score   (root_mean_squared_error)
# 	5.91s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ...
# 	-3.5538	 = Validation score   (root_mean_squared_error)
# 	0.65s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ...
# 	-3.8365	 = Validation score   (root_mean_squared_error)
# 	4.01s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ...
# 	-3.2135	 = Validation score   (root_mean_squared_error)
# 	3.51s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetMXNet_BAG_L1 ...
# 	Warning: Exception caused NeuralNetMXNet_BAG_L1 to fail during training (ImportError)... Skipping this model.
# 		Unable to import dependency mxnet. A quick tip is to install via `pip install mxnet --upgrade`, or `pip install mxnet_cu101 --upgrade`
# Fitting model: LightGBMLarge_BAG_L1 ...
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# [1000]	train_set's rmse: 0.0174829	valid_set's rmse: 3.90217
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:239: UserWarning: 'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose_eval' argument is deprecated and will be removed in a future release of LightGBM. "
# 	-3.4451	 = Validation score   (root_mean_squared_error)
# 	4.44s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	-3.0545	 = Validation score   (root_mean_squared_error)
# 	0.33s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 26.42s ...
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20220303_012701/")
#                      model    score_test  ...  can_infer  fit_order
# 0    KNeighborsDist_BAG_L1 -5.547304e-07  ...       True          2
# 1           XGBoost_BAG_L1 -7.263038e-01  ...       True          9
# 2     LightGBMLarge_BAG_L1 -1.101819e+00  ...       True         10
# 3          CatBoost_BAG_L1 -1.115920e+00  ...       True          6
# 4      WeightedEnsemble_L2 -1.135708e+00  ...       True         11
# 5   RandomForestMSE_BAG_L1 -1.216550e+00  ...       True          5
# 6     ExtraTreesMSE_BAG_L1 -1.292980e+00  ...       True          7
# 7          LightGBM_BAG_L1 -1.631465e+00  ...       True          4
# 8        LightGBMXT_BAG_L1 -1.908647e+00  ...       True          3
# 9   NeuralNetFastAI_BAG_L1 -3.038508e+00  ...       True          8
# 10   KNeighborsUnif_BAG_L1 -5.211792e+00  ...       True          1
#
# [11 rows x 12 columns]

# %%
# Making Predictions
y_pred = predictor.predict(test_data)

# %%
y_pred
# Out:
# 307    29.221838
# 343    26.769907
# 47     19.751644
# 67     20.383785
# 362    21.184814
#          ...
# 249    26.300903
# 421    16.082914
# 422    18.622097
# 286    20.771666
# 347    24.698534
# Name: PRICE, Length: 167, dtype: float32
